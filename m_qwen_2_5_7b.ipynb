# %%
# !pip uninstall -y torch torchvision torchaudio bitsandbytes accelerate transformers
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# WARNING: Skipping bitsandbytes as it is not installed.
# Found existing installation: accelerate 1.7.0
# Uninstalling accelerate-1.7.0:
#   Successfully uninstalled accelerate-1.7.0
# Found existing installation: transformers 4.52.2
# Uninstalling transformers-4.52.2:
#   Successfully uninstalled transformers-4.52.2

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 99.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 51.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 117.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 MB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.8 MB/s eta 0:00:00
# ...

# %%
# !pip install bitsandbytes accelerate transformers
# !git clone https://github.com/arcee-ai/mergekit.git
# %cd mergekit
# !pip install -e .
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.1/362.1 kB 29.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 94.3 MB/s eta 0:00:00
# ...
# Cloning into 'mergekit'...
# remote: Enumerating objects: 3154, done.
# remote: Counting objects: 100% (1304/1304), done.
# remote: Compressing objects: 100% (403/403), done.
# remote: Total 3154 (delta 1126), reused 902 (delta 901), pack-reused 1850 (from 4)
# Receiving objects: 100% (3154/3154), 1.09 MiB | 12.28 MiB/s, done.
# Resolving deltas: 100% (2153/2153), done.
# /content/mergekit
# Obtaining file:///content/mergekit
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 8.5 MB/s eta 0:00:00
# ...

# %%
OUTPUT_PATH="./models/qwen-2.5-7b-mergedl"
LORA_MERGE_CACHE="/tmp"
CONFIG_YML="/content/mergekit/tests/linear.yml"
COPY_TOKENIZER=True
LAZY_UNPICKLE=False
LOW_CPU_MEMORY=False
import torch
import yaml

from mergekit.config import MergeConfiguration
from mergekit.merge import MergeOptions, run_merge

with open(CONFIG_YML, "r", encoding="utf-8") as fp:
  merge_config =MergeConfiguration.model_validate(yaml.safe_load(fp))

run_merge(
    merge_config,
    out_path=OUTPUT_PATH,
    options=MergeOptions(
        lora_merge_cache=LORA_MERGE_CACHE,
        cuda=torch.cuda.is_available(),
        copy_tokenizer=COPY_TOKENIZER,
        lazy_unpickle=LAZY_UNPICKLE,
        low_cpu_memory = LOW_CPU_MEMORY,
    ),
)
print("done")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/728 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/728 [00:00<?, ?B/s]
# ...
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
# !pip uninstall torch_xla -y
# Out:
# WARNING: Skipping torch_xla as it is not installed.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

tokenizer = AutoTokenizer.from_pretrained("/content/mergekit/models/qwen-2.5-7b-mergedl")
model = AutoModelForCausalLM.from_pretrained("/content/mergekit/models/qwen-2.5-7b-mergedl", torch_dtype=torch.float16, device_map="auto")

user_message="give python code of fibonacci series"
prompt=f"""below is an instruction
###instruction
{user_message}

###response
"""

inputs=tokenizer(prompt, return_tensors="pt").to(model.device)
outputs=model.generate(**inputs,max_new_tokens=256, num_beams=1, early_stopping=True, no_repeat_ngram_size=2,)
result=tokenizer.batch_decode(outputs, skip_special_tokens=True)
print(result[0])
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# below is an instruction
# ###instruction
# give python code of fibonacci series
#
# ###response
# Certainly! Below is a simple Python code to generate the Fibonacci series up to a specified number of terms:
#
# ```python
# def fibonacci_series(n):
#     if n <= 0:
#         return []
#     elif n == 1:
#        return [0]
#     else:
#          fib_series = [1, 2]
#          for i in range(2, n):
#              next_term = fib.Series[-1] + fib.Seris[-2]
#              fib_Series.append(next_term)
#          return fib_seris
#
# # Example usage:
# num_terms = 8
# print(fibonacci_series(num_terms))
# ```
#
# ...

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
model.push_to_hub("Primus11/qwen-2.5-7b-mergedl2")
tokenizer.push_to_hub("Primus11/qwen-2.5-7b-mergedl2")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-8-a0fcb097aabd> in <cell line: 0>()
# ----> 1 model.push_to_hub("Primus11/qwen-2.5-7b-mergedl2")
# ...

# %%
from transformers import AutoConfig, AutoModel, AutoTokenizer
config=AutoConfig.from_pretrained("Primus11/qwen-2.5-7b-mergedl")
model=AutoModel.from_pretrained("Primus11/qwen-2.5-7b-mergedl")
tokenizer=AutoTokenizer.from_pretrained("Primus11/qwen-2.5-7b-mergedl")
